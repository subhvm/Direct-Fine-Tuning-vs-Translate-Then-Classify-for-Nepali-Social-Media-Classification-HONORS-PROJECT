# %%
import pandas as pd

df1 = pd.read_csv('twitter_test_en.csv')
df2 = pd.read_csv('twitter_train_en.csv')
df3 = pd.read_csv('twitter_val_en.csv')

# %%
df1[["text", "text_en"]].sample(20)
# Out:
#                                                    text  \
# 549   सुदूरपश्चिम प्रदेशका मन्त्रीहरूले एक महीनाको प...
# 211   सम्माननिय ज्यू तपाईको कुरा सबै पत्यायौ र समर्थ...
# 4512    कोभिड काठमाडौँमा बजार खोल्न नदिने सरकारी निर्णय
# 1669  कोरोना भाइरस कोभिड को परीक्षण र उपचार आफ्नै खर...
# 1705                       कोभिड निको हुन कति समय लाग्छ
# 4933      भारतमा कोभिड बाट एकै दिन झण्डै हजार सङ्क्रमित
# 1253  कोभिड कोरोना रोकथामका लागि मेडिकल सामान बोकेर ...
# 865   कोभिड को संक्रमणको त्रासले काठमाडौं उपत्यकाबाट...
# 851   कोरोना भाइरस कोभिड फैलिएपछि चीनबाट स्वदेश फर्क...
# 1739  कोभिड बीपी प्रतिष्ठानमा उपचाररत झापाका संक्रमि...
# 2063  ईस्लाम धर्मावलम्बीहरुको पवित्र महिना रमजानको प...
# 2399  स्वास्थ्य मन्त्रालयको कोभिड प्रेस बिफ्रिङ दैनि...
# 2906  यतिखेर कोभिड भ्याक्सिनको परीक्षण त्यसले काम गर...
# 1128  कोरोना भाइरस खोप कोभिड विरुद्ध विकसित अर्को खो...
# 1236  विश्व भरी जो जहाँ छ त्यो त्यही सेल्फ क्वारेन्ट...
# 508   कोभिड रोकथाम तथा नियन्त्रण उच्चस्तरीय समन्वय स...
# ...

# %%
df2[["text", "text_en"]].sample(20)
# Out:
#                                                     text  \
# 19986      के आइलाग्यो बरीलै सिम्टोम त कोभिड सँग मिल्छ त
# 14802  घण्टाभित्र ललितपुरमा कोभिड संक्रमित तीन जनाको ...
# 10155  ले कोरोना भाईरस कोभिड को संक्रमण रोकथाम तथा नि...
# 19846  टोल टोलमा पढाउँदै शिक्षक कोरोना भाइरस कोभिड सङ...
# 13114  कोभिड संग लडन सक्ने हिम्मत र साहस संगै हामी जि...
# 13769  कोभिड महामारीविरुद्धको लडाइँमा भारतले नेपाललाई...
# 1952   कोभिड ले विश्वकै आर्थिक वृद्धिमा असर पर्नसक्छ ...
# 12030  कोभिड को समस्य समाधान को लागि लडाइँमा उहाँ को ...
# 17572  कोभिड को जोखिमलाई दृष्टिगत गरी अझै दुई महिना श...
# 15868   आफैं कोभिड को नमूना परीक्षण गराउन रू हजार लाग्ने
# 21348  भारतमा पछिल्लो घण्टामा कोरोना भाइरस कोभिड का ह...
# 4749            नेपालमा प्रतिशतलाई कोभिड खोप दिइने तयारी
# 9271   आगामी वर्षको बजेट कोभिड को प्रभाव न्यूनीकरणमा ...
# 14903  कोरोनाभाइरस कोभिड प्रकोप फैलिएको चीनको वुहानबा...
# 1613             युवा पनि कोभिड को उच्च जोखिममा डब्लूएचओ
# ...

# %%
df3[["text", "text_en"]].sample(20)
# Out:
#                                                    text  \
# 4370    कोभिड को खोप निर्माण युद्धमा चीन सबैभन्दा अगाडि
# 926   अबको केहि दिन टियलमा कोरोना कोभिड जस्ता शब्द प...
# 508   कोभिड महामारी नियन्त्रण न सरकारको एक्लो प्रयास...
# 1701  लामखुट्टेले टोक्दा डेङ्गु कुकुरले टोक्दा रेबिज...
# 9     सरकारले यो सातादेखि उपत्यकाबाहिरका सात स्थानमा...
# 2553  कोभिड अन्त्यको अनिश्चितताका बेला इन्टरनेटको आव...
# 2966  औं विश् व स्वास्थ्य महासभालाई आज बिहान सम्बोधन...
# 3095  स्वास्थ्य तथा जनसंख्या मन्त्रालयले कोभिड एन्टि...
# 3912                 कोभिड बाट नेपालमा कुल जना संक्रमित
# 4131  दिल्लीमा आइतबार कोभिड सङ्क्रमितभन्दा निको हुने...
# 3687  आलोचना भएपछि सरकारले नयाँ नियम ल्याएछ स्वघोषणा...
# 2800                       कोभिड को असर चुनौती तथा अवसर
# 1239  कोसी अस्पतालको कोभिड उपचार केन्द्रमा थप कोरोना...
# 511   संसारको तीब्र कम्प्युटरले पहिचान गर्यो कोभिड व...
# 3581  ए बिबेक सुन्य ख्वामित बढाएर मात्र कोभिड कन्ट्र...
# 2292  कोभिड ले निको पार्छ भन्ने न्यूज भाइरल भइरहेको ...
# ...
